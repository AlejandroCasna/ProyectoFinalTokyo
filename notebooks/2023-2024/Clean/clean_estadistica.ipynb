# %%
import sys
sys.path.append('C:/Users/Alejandro/Proyectos/Tokioschool/Modulo_6/VoleyStats-Pro-run') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=124&PID=152'
parametro = 'estadistica_equipo'
dato=scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
columna = ['Equipo', 'Jugados', 'Sets_Jugados', 'Total_Puntos', 'Break_Puntos', 'Puntos_Ganados',
            'Puntos_Perdidos', 'Total_Saque', 'Puntos_Saque', 'Error_Saque', 'Puntos_por_set_Saque',
            'Efic_Saque', 'Total_Recepcion', 'Error_Recepcion', 'Negativo_Recepcion', 'Positivo_Recepcion',
            'Excelente_Recepcion', 'Efic_Recepcion', 'Total_Ataque', 'Error_Ataque', 'Ataque_Bloqueado',
            'Positivo_Ataque', 'Excelente_Ataque', 'Efic_Ataque', 'Toque_Red_Bloqueo', 'Puntos_de_Bloqueo',
            'Puntos_Set_Bloqueo']

parametro = 'estadistica'
estadistica=crear_df(dato,columna,parametro)

# %%
mapear_nombres(estadistica)
normalizar_df(estadistica)
# Out:
#                   Equipo  Jugados  Sets_Jugados  Total_Puntos  Break_Puntos  \
# 0        Rio Duero Soria       15            56           959           366
# 1            Voley Palma       15            60           934           327
# 2         Cisneros Alter       15            56           909           296
# 3                Guaguas       15            53           883           382
# 4   Conqueridor Valencia       14            55           867           321
# 5              CV Teruel       15            55           862           299
# 6                Manacor       15            53           848           298
# 7           CV San Roque       14            56           837           278
# 8           Arenal Emeve       14            54           812           272
# 9             CV Melilla       15            49           806           312
# 10       Unicaja Almeria       14            50           803           312
# 11     CV Villena Petrer       15            51           702           208
#
#     Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  Error_Saque  \
# 0              593              478         1314            61          208
# 1              607              322         1283            81          211
# 2              613              363         1259            59          228
# 3              501              460         1249            93          182
# 4              546              344         1200            81          190
# 5              563              380         1235            39          185
# 6              550              379         1154            78          155
# 7              559              299         1190            64          199
# 8              540              291         1078            39          184
# 9              494              357         1141            72          187
# 10             491              390         1109            78          190
# 11             494              204         1080            32          172
#
#     ...  Efic_Recepcion  Total_Ataque  Error_Ataque  Ataque_Bloqueado  \
# 0   ...            22.0          1530            89               108
# 1   ...            25.0          1726           176               151
# 2   ...            27.0          1496           133               117
# 3   ...            26.0          1320            89                84
# 4   ...            15.0          1528           144               119
# 5   ...            22.0          1430           128               114
# 6   ...            27.0          1410           118               118
# 7   ...            26.0          1433           134               119
# 8   ...            28.0          1467           145               132
# 9   ...            32.0          1292            86               103
# 10  ...            25.0          1208            82                87
# 11  ...            32.0          1466           117               150
#
#     Positivo_Ataque  Excelente_Ataque  Efic_Ataque  Toque_Red_Bloqueo  \
# 0               751              49.0         36.0                219
# 1               737              43.0         24.0                121
# 2               737              49.0         33.0                 39
# 3               654              50.0         36.0                123
# 4               684              45.0         28.0                208
# 5               673              47.0         30.0                190
# 6               647              46.0         29.0                104
# 7               668              47.0         29.0                128
# 8               650              44.0         25.0                117
# 9               625              48.0         34.0                165
# 10              628              52.0         38.0                192
# 11              589              40.0         22.0                 95
#
#     Puntos_de_Bloqueo  Puntos_Set_Bloqueo
# 0                 147                 2.6
# 1                 116                 1.9
# 2                 113                 2.0
# 3                 136                 2.6
# 4                 102                 1.9
# 5                 150                 2.7
# 6                 123                 2.3
# 7                 105                 1.9
# 8                 123                 2.3
# 9                 109                 2.2
# 10                 97                 1.9
# 11                 81                 1.6
#
# [12 rows x 27 columns]

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../../data/2023-2024/Equipos.csv')
df
# Out:
#                   Equipo     id_equipo
# 0           Arenal Emeve   1-2023-2024
# 1         Cisneros Alter   2-2023-2024
# 2            Voley Palma   3-2023-2024
# 3                Manacor   4-2023-2024
# 4                Guaguas   5-2023-2024
# 5             CV Melilla   6-2023-2024
# 6           CV San Roque   7-2023-2024
# 7        Rio Duero Soria   8-2023-2024
# 8              CV Teruel   9-2023-2024
# 9        Unicaja Almeria  10-2023-2024
# 10  Conqueridor Valencia  11-2023-2024
# 11     CV Villena Petrer  12-2023-2024

# %%
result = pd.merge(estadistica, df[['Equipo', 'id_equipo']], left_on='Equipo', right_on='Equipo', how='left')
result['temporada']='2023-2024'
result.info()
result.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Equipo                12 non-null     object
#  1   Jugados               12 non-null     int64
#  2   Sets_Jugados          12 non-null     int64
#  3   Total_Puntos          12 non-null     int64
#  4   Break_Puntos          12 non-null     int64
#  5   Puntos_Ganados        12 non-null     int64
#  6   Puntos_Perdidos       12 non-null     int64
#  7   Total_Saque           12 non-null     int64
#  8   Puntos_Saque          12 non-null     int64
#  9   Error_Saque           12 non-null     int64
#  10  Puntos_por_set_Saque  12 non-null     float64
#  11  Efic_Saque            12 non-null     float64
#  12  Total_Recepcion       12 non-null     int64
#  13  Error_Recepcion       12 non-null     int64
#  14  Negativo_Recepcion    12 non-null     int64
#  15  Positivo_Recepcion    12 non-null     int64
#  16  Excelente_Recepcion   12 non-null     float64
#  17  Efic_Recepcion        12 non-null     float64
#  18  Total_Ataque          12 non-null     int64
#  19  Error_Ataque          12 non-null     int64
#  20  Ataque_Bloqueado      12 non-null     int64
#  21  Positivo_Ataque       12 non-null     int64
#  22  Excelente_Ataque      12 non-null     float64
#  23  Efic_Ataque           12 non-null     float64
#  24  Toque_Red_Bloqueo     12 non-null     int64
#  25  Puntos_de_Bloqueo     12 non-null     int64
#  26  Puntos_Set_Bloqueo    12 non-null     float64
#  27  id_equipo             12 non-null     object
#  28  temporada             12 non-null     object
# dtypes: float64(7), int64(19), object(3)
# memory usage: 2.8+ KB
#             Equipo  Jugados  Sets_Jugados  Total_Puntos  Break_Puntos  \
# 0  Rio Duero Soria       15            56           959           366
# 1      Voley Palma       15            60           934           327
#
#    Puntos_Ganados  Puntos_Perdidos  Total_Saque  Puntos_Saque  Error_Saque  \
# 0             593              478         1314            61          208
# 1             607              322         1283            81          211
#
#    ...  Error_Ataque  Ataque_Bloqueado  Positivo_Ataque  Excelente_Ataque  \
# 0  ...            89               108              751              49.0
# 1  ...           176               151              737              43.0
#
#    Efic_Ataque  Toque_Red_Bloqueo  Puntos_de_Bloqueo  Puntos_Set_Bloqueo  \
# 0         36.0                219                147                 2.6
# 1         24.0                121                116                 1.9
#
#      id_equipo  temporada
# 0  8-2023-2024  2023-2024
# 1  3-2023-2024  2023-2024
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Guardado en CSV.

# %%
result.to_csv('../../../data/2023-2024/estadistica.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
key = 'id_equipo'
dtype = {key: Integer}
estadistica.to_sql('estadistica', engine, if_exists='append', index=False)
# Out:
# 12
