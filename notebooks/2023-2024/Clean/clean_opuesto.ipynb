# %%
import sys
sys.path.append('C:/Users/Alejandro/Proyectos/Tokioschool/Modulo_6/VoleyStats-Pro-run') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=124&PID=152'
parametro='estadistica_jugador'
datos = scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
columna = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Bloqueos', 'Bloqueo_exitoso',
                'Bloqueo_fallido', 'Total_bloqueos', 'Saque','Errores_Saque', 'Porcentaje_error',
                'Total_saques', 'Ataque_exitoso','Errores_ataque','Porc_error','Total_ataques','Ataque_Ranking',17]
parametro= 'estadistica_opuesto'
opuesto = crear_df(datos[3],columna,parametro)
opuesto.drop([1,17], inplace=True, axis=1)
opuesto.head(2)
# Out:
#              Nombre Partidos_jugados Sets_jugados Bloqueos Bloqueo_exitoso  \
# 0     Dahl Ulrik Bo               14           56       40              50
# 1  Martina Federico               15           47        4               6
#
#   Bloqueo_fallido Total_bloqueos Saque Errores_Saque Porcentaje_error  \
# 0              25            243    17            22                0
# 1               2            115    11            19                1
#
#   Total_saques Ataque_exitoso Errores_ataque Porc_error Total_ataques  \
# 0           45            270             51         52           590
# 1           50            168             11         24           322
#
#   Ataque_Ranking
# 0         2,7143
# 1         2,5957

# %%
normalizar_df(opuesto)
# Out:
#                               Nombre Partidos_jugados Sets_jugados Bloqueos  \
# 0                      Dahl Ulrik Bo               14           56       40
# 1                   Martina Federico               15           47        4
# 2                 Santos Cunha Bruno               15           56       16
# 3                  Linares Jose Luis               13           48       17
# 4              Rodriguez Dosal Angel               15           60       32
# 5       Nogueira Amorim Victor Lucas               13           47       12
# 6             Neaves Matthew Michael               14           47       19
# 7     Martinez Palacios Miguel Angel               14           44        3
# 8            Pereyra Hernan Federico                4           13        2
# 9   Bezerra Souza Francisco Wallyson               14           43       14
# 10              Danger Mulen Armando               14           53       16
# 11             Osorio Recorda Gerard               15           51        7
# 12        Moreno Mosquera Juan Pablo                9           21        3
# 13    Chourio Gonzalez Anderson Jose                4            6        0
#
#    Bloqueo_exitoso Bloqueo_fallido Total_bloqueos Saque Errores_Saque  \
# 0               50              25            243    17            22
# 1                6               2            115    11            19
# 2               39              16            218    20            27
# 3               37              11            150    11             8
# 4               44              13            242    20            14
# 5               37               6            139    18             3
# 6               48               9            164    10            28
# 7               21               5            123    21            16
# 8                7               5             35     7             6
# 9               31               7            139    11            19
# 10              29               5            147    10            27
# 11              56               5            140    14             7
# 12              15               7             67     2             9
# 13               0               0              9     1             1
#
#    Porcentaje_error Total_saques Ataque_exitoso Errores_ataque Porc_error  \
# 0                 0           45            270             51         52
# 1                 1           50            168             11         24
# 2                 2           83            250             33         42
# 3                 0           27            223             47         41
# 4                 0           50            294             81         60
# 5                 0           24            188             41         34
# 6                 0           64            209             29         31
# 7                 1           60            148             37         22
# 8                 0           17             44              6         13
# 9                 0           42            116             14         24
# 10                0           75            171             42         36
# 11                0           43            192             33         62
# 12                0           19             62             12         12
# 13                0            8              5              4          5
#
#    Total_ataques Ataque_Ranking
# 0            590         2,7143
# 1            322         2,5957
# 2            533         2,5536
# 3            461         2,4583
# 4            651         2,4500
# 5            365         2,1915
# 6            395         2,1702
# 7            327         1,7045
# 8             89         1,6154
# 9            264         1,2326
# 10           384         1,1887
# 11           473         1,0784
# 12           115         0,9048
# 13            18        -0,6667

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../../data/2023-2024/Jugadores.csv')
df
# Out:
#      Dorsal                          Nombre        Posicion  Altura  \
# 0         2          Paradela Corton Miguel          Libero     0.0
# 1         3           Bouza Ferreiro Victor        Receptor     0.0
# 2         4               Linares Jose Luis         Opuesto     0.0
# 3         5        Barrasa Portomene Samuel          Libero     0.0
# 4         6           Edward Batalla Dexter     Colocador/a     0.0
# ..      ...                             ...             ...     ...
# 163      15              Mari Domene Alvaro  Middle-blocker   198.0
# 164      17           Martinez Gomez Sergio         Opuesto   190.0
# 165      20  Hernandez Robeff Tomas Agustin        Receptor   190.0
# 166      23          Jimenez Gallego Carlos        Receptor   193.0
# 167      77   Fernandez Rodriguez Francisco        Receptor     0.0
#
#      Ano_de_nacimiento  Alcance_en_ataque  Alcance_en_bloqueo     id_jugador  \
# 0                 2004                0.0                 0.0    1-2023-2024
# 1                 1990                0.0                 0.0    2-2023-2024
# 2                 1998                0.0                 0.0    3-2023-2024
# 3                 2007                0.0                 0.0    4-2023-2024
# 4                 2000                0.0                 0.0    5-2023-2024
# ..                 ...                ...                 ...            ...
# 163               2002              333.0               315.0  164-2023-2024
# 164               2002              329.0               309.0  165-2023-2024
# 165               1998              329.0               308.0  166-2023-2024
# 166               1995              346.0               320.0  167-2023-2024
# 167               1996                0.0                 0.0  168-2023-2024
#
#      temporada     id_equipo
# 0    2023-2024   1-2023-2024
# 1    2023-2024   1-2023-2024
# 2    2023-2024   1-2023-2024
# 3    2023-2024   1-2023-2024
# 4    2023-2024   1-2023-2024
# ..         ...           ...
# 163  2023-2024  12-2023-2024
# 164  2023-2024  12-2023-2024
# 165  2023-2024  12-2023-2024
# 166  2023-2024  12-2023-2024
# 167  2023-2024  12-2023-2024
#
# [168 rows x 10 columns]

# %%
opuesto = pd.merge(opuesto, df[['Nombre', 'id_jugador','id_equipo']], on='Nombre', how='left')
opuesto['temporada']='2023-2024'
convertir = opuesto.columns.difference(['Nombre','id_jugador','id_equipo','temporada','Ataque_Ranking'])
opuesto['Ataque_Ranking'] = opuesto['Ataque_Ranking'].str.replace(',', '.').astype(float)
opuesto[convertir] = opuesto[convertir].applymap(lambda x: int(x) if str(x).isdigit() else x)
opuesto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nombre            14 non-null     object
#  1   Partidos_jugados  14 non-null     int64
#  2   Sets_jugados      14 non-null     int64
#  3   Bloqueos          14 non-null     int64
#  4   Bloqueo_exitoso   14 non-null     int64
#  5   Bloqueo_fallido   14 non-null     int64
#  6   Total_bloqueos    14 non-null     int64
#  7   Saque             14 non-null     int64
#  8   Errores_Saque     14 non-null     int64
#  9   Porcentaje_error  14 non-null     int64
#  10  Total_saques      14 non-null     int64
#  11  Ataque_exitoso    14 non-null     int64
#  12  Errores_ataque    14 non-null     int64
#  13  Porc_error        14 non-null     int64
#  14  Total_ataques     14 non-null     int64
#  15  Ataque_Ranking    14 non-null     float64
#  16  id_jugador        14 non-null     object
#  17  id_equipo         14 non-null     object
#  18  temporada         14 non-null     object
# dtypes: float64(1), int64(14), object(4)
# memory usage: 2.2+ KB

# %% [markdown]
# ## Guardado en CSV.

# %%
opuesto.to_csv('../../../data/2023-2024/opuesto.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
dtype = {'id_jugador': Integer}
opuesto.to_sql('opuesto', engine, if_exists='append', index=False, dtype=dtype)
# Out:
# 15
