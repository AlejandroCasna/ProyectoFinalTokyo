# %%
import sys
sys.path.append('C:/Users/Alejandro/Proyectos/Tokioschool/Modulo_6/VoleyStats-Pro-run') # Hablar con el jefe
from src.help_scraping import *
from src.help_datos import *

# %%
url = 'https://rfevb-web.dataproject.com/Statistics.aspx?ID=124&PID=152'
parametro = 'estadistica_jugador'
datos = scraping(url,parametro)
# Out:
# hola
# No se pudo hacer clic en el botón de cookies.
# Scraping exitoso

# %%
    
columna = ['Nombre', 1, 'Partidos_jugados', 'Sets_jugados', 'Acciones_exitosas', 'Errores_colocador',
                '_error_colocador', 'Puntos_negativos', 'Puntos_positivos',
                'Acciones_positivas', 'Total_acumulado', 'Efic_Ranking',2]

parametro= 'estadistica_colocador'
colocador = crear_df(datos[5],columna,parametro)
colocador.drop([1,2], inplace=True, axis=1)
colocador.reset_index(inplace=True)
normalizar_df(colocador)
colocador.head(2)
# Out:
#    index                  Nombre Partidos_jugados Sets_jugados  \
# 0      0     Cavanna Maximiliano                2            4
# 1      1  Bertassoni Paulo Renan               14           47
#
#   Acciones_exitosas Errores_colocador _error_colocador Puntos_negativos  \
# 0                21                 0                3                3
# 1               268                 9               24               73
#
#   Puntos_positivos Acciones_positivas Total_acumulado Efic_Ranking
# 0                4                  3              34       0,4412
# 1               28                 32             434       0,3756

# %%
#Extraccion de jugadores.
df= pd.read_csv('../../../data/2023-2024/jugadores.csv')
df.head(2)
# Out:
#    Dorsal                  Nombre  Posicion  Altura  Ano_de_nacimiento  \
# 0       2  Paradela Corton Miguel    Libero     0.0               2004
# 1       3   Bouza Ferreiro Victor  Receptor     0.0               1990
#
#    Alcance_en_ataque  Alcance_en_bloqueo   id_jugador  temporada    id_equipo
# 0                0.0                 0.0  1-2023-2024  2023-2024  1-2023-2024
# 1                0.0                 0.0  2-2023-2024  2023-2024  1-2023-2024

# %%
colocador = pd.merge(colocador, df[['Nombre', 'id_jugador','id_equipo']], on='Nombre', how='left')
colocador['temporada']='2022-2023'
colocador.drop(['index'], axis=1, inplace=True)
colocador.head(2)
# Out:
#                    Nombre Partidos_jugados Sets_jugados Acciones_exitosas  \
# 0     Cavanna Maximiliano                2            4                21
# 1  Bertassoni Paulo Renan               14           47               268
#
#   Errores_colocador _error_colocador Puntos_negativos Puntos_positivos  \
# 0                 0                3                3                4
# 1                 9               24               73               28
#
#   Acciones_positivas Total_acumulado Efic_Ranking     id_jugador  \
# 0                  3              34       0,4412   65-2023-2024
# 1                 32             434       0,3756  133-2023-2024
#
#       id_equipo  temporada
# 0   5-2023-2024  2022-2023
# 1  10-2023-2024  2022-2023

# %%
colocador
# Out:
#                         Nombre Partidos_jugados Sets_jugados  \
# 0          Cavanna Maximiliano                2            4
# 1       Bertassoni Paulo Renan               14           47
# 2              Roberts Ignacio               11           42
# 3          Riganti Juan Martin               15           49
# 4          Lorente Lopez Lucas               12           43
# 5        Lorente Camacho Ruben               13           45
# 6          de Amo Miguel Angel               12           40
# 7           Martin Perez Cesar               12           42
# 8      Arjones Ferreiros Jaime               13           51
# 9         Pont Perello Guillem                8           18
# 10      Monfort Minaya Vicente               14           54
# 11  Loeches Buitrago Guillermo               12           49
# 12                                           17           30
# 13       Edward Batalla Dexter               13           48
# 14        Garcia Borras Hector               15           51
# 15    Castaneda Yanguas Daniel                4           11
#
#    Acciones_exitosas Errores_colocador _error_colocador Puntos_negativos  \
# 0                 21                 0                3                3
# 1                268                 9               24               73
# 2                286                 2               36               64
# 3                289                 0               36               73
# 4                251                 5               30               74
# 5                220                 7               32               65
# 6                199                 0               18               75
# 7                241                 4               44               82
# 8                289                 7               49               69
# 9                 54                 0                6               24
# 10               242                 4               36               88
# 11               253                 2               32               98
# 12               146                 0               20               67
# 13               268                 2               58              108
# 14               288                 5               68              150
# 15                16                 0                3                8
#
#    Puntos_positivos Acciones_positivas Total_acumulado Efic_Ranking  \
# 0                 4                  3              34       0,4412
# 1                28                 32             434       0,3756
# 2                50                 42             480       0,3750
# 3                83                 27             508       0,3720
# 4                55                 20             435       0,3609
# 5                42                 35             401       0,2993
# 6                39                 25             356       0,2781
# 7                43                 35             449       0,2762
# 8               151                 57             622       0,2621
# 9                14                  4             102       0,2549
# 10               54                 37             461       0,2538
# 11               42                 38             465       0,2516
# 12               26                 20             279       0,2115
# 13               65                 58             559       0,1825
# 14               94                 48             653       0,1378
# 15                3                  4              34       0,1176
#
#        id_jugador     id_equipo  temporada
# 0    65-2023-2024   5-2023-2024  2022-2023
# 1   133-2023-2024  10-2023-2024  2022-2023
# 2    23-2023-2024   2-2023-2024  2022-2023
# 3    80-2023-2024   6-2023-2024  2022-2023
# 4    97-2023-2024   8-2023-2024  2022-2023
# 5   116-2023-2024   9-2023-2024  2022-2023
# 6    59-2023-2024   5-2023-2024  2022-2023
# 7    51-2023-2024   4-2023-2024  2022-2023
# 8    39-2023-2024   3-2023-2024  2022-2023
# 9   122-2023-2024   9-2023-2024  2022-2023
# 10  147-2023-2024  11-2023-2024  2022-2023
# 11   88-2023-2024   6-2023-2024  2022-2023
# 12            NaN           NaN  2022-2023
# 13    5-2023-2024   1-2023-2024  2022-2023
# 14  156-2023-2024  12-2023-2024  2022-2023
# 15   87-2023-2024   6-2023-2024  2022-2023

# %%
colocador.drop(12, inplace=True)

# %%
convertir = colocador.columns.difference(['Nombre'])
colocador['Efic_Ranking'] = colocador['Efic_Ranking'].str.replace(',', '.').astype(float)
colocador[convertir] = colocador[convertir].applymap(lambda x: int(x) if str(x).isdigit() else x)
colocador['temporada']='2023-2024'
colocador.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 15
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Nombre              15 non-null     object
#  1   Partidos_jugados    15 non-null     int64
#  2   Sets_jugados        15 non-null     int64
#  3   Acciones_exitosas   15 non-null     int64
#  4   Errores_colocador   15 non-null     int64
#  5   _error_colocador    15 non-null     int64
#  6   Puntos_negativos    15 non-null     int64
#  7   Puntos_positivos    15 non-null     int64
#  8   Acciones_positivas  15 non-null     int64
#  9   Total_acumulado     15 non-null     int64
#  10  Efic_Ranking        15 non-null     float64
#  11  id_jugador          15 non-null     object
#  12  id_equipo           15 non-null     object
#  13  temporada           15 non-null     object
# dtypes: float64(1), int64(9), object(4)
# memory usage: 1.8+ KB

# %%
normalizar('../../../data/2023-2024/colocador.csv')
# Out:
#                         Nombre  Partidos_jugados  Sets_jugados  \
# 0          Cavanna Maximiliano                 2             4
# 1       Bertassoni Paulo Renan                 9            29
# 2          Riganti Juan Martin                 9            31
# 3              Roberts Ignacio                 8            32
# 4          Lorente Lopez Lucas                 7            26
# 5           Martin Perez Cesar                 8            27
# 6      Arjones Ferreiros Jaime                 7            28
# 7   Loeches Buitrago Guillermo                 8            34
# 8        Lorente Camacho Ruben                 9            31
# 9         Pont Perello Guillem                 7            15
# 10         de Amo Miguel Angel                 9            31
# 11      Monfort Minaya Vicente                 9            36
# 12        Garcia Borras Hector                 9            32
# 13       Edward Batalla Dexter                 8            30
#
#     Acciones_exitosas  Errores_colocador  _error_colocador  Puntos_negativos  \
# 0                  21                  0                 3                 3
# 1                 166                  2                13                39
# 2                 199                  0                25                46
# 3                 216                  2                26                45
# 4                 153                  4                17                47
# 5                 158                  4                30                50
# 6                 161                  3                24                38
# 7                 187                  2                20                67
# 8                 153                  6                27                47
# 9                  51                  0                 6                22
# 10                157                  0                15                62
# 11                155                  1                24                55
# 12                186                  5                40                75
# 13                176                  0                39                64
#
#     Puntos_positivos  Acciones_positivas  Total_acumulado  Efic_Ranking  \
# 0                  4                   3               34        0.4412
# 1                 19                  15              254        0.4409
# 2                 63                  19              352        0.3807
# 3                 32                  37              358        0.3743
# 4                 36                  10              267        0.3596
# 5                 30                  24              296        0.2838
# 6                 74                  30              330        0.2818
# 7                 31                  27              334        0.2784
# 8                 32                  26              291        0.2749
# 9                 13                   4               96        0.2604
# 10                30                  22              286        0.2552
# 11                35                  26              296        0.2500
# 12                58                  24              388        0.2242
# 13                44                  36              359        0.2117
#
#        id_jugador     id_equipo  temporada
# 0    65-2023-2024   5-2023-2024  2023-2024
# 1   133-2023-2024  10-2023-2024  2023-2024
# 2    80-2023-2024   6-2023-2024  2023-2024
# 3    23-2023-2024   2-2023-2024  2023-2024
# 4    97-2023-2024   8-2023-2024  2023-2024
# 5    51-2023-2024   4-2023-2024  2023-2024
# 6    39-2023-2024   3-2023-2024  2023-2024
# 7    88-2023-2024   6-2023-2024  2023-2024
# 8   116-2023-2024   9-2023-2024  2023-2024
# 9   122-2023-2024   9-2023-2024  2023-2024
# 10   59-2023-2024   5-2023-2024  2023-2024
# 11  147-2023-2024  11-2023-2024  2023-2024
# 12  156-2023-2024  12-2023-2024  2023-2024
# 13    5-2023-2024   1-2023-2024  2023-2024

# %% [markdown]
# ## Guardado en CSV.

# %%
colocador.to_csv('../../../data/2023-2024/colocador.csv', index=False)

# %% [markdown]
# ## Base de datos.

# %%
with open('../../../pass.txt', 'r') as file:   # pass.txt en .gitignore
    
    pass_ = file.read()

# %%
str_conn = f'mysql+pymysql://root:{pass_}@localhost:3306/'
conn = create_engine(str_conn)
engine = create_engine(f'mysql+pymysql://root:{pass_}@localhost:3306/volleyballdb')

# %%
dtype = {'id_jugador': Integer}
colocador.to_sql('colocador', engine, if_exists='append', index=False)
# Out:
# 14
